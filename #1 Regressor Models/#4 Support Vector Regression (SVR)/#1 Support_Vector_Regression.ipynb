# %% [markdown]
# # Support Vector Regression (SVR)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Data/Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
y = y.reshape(len(y), 1)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scale_x = StandardScaler()
scale_y = StandardScaler()
x = scale_x.fit_transform(x)
y = scale_y.fit_transform(y)

# %% [markdown]
# ## Training the SVR model on the whole dataset

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(x, y)
# Out:
# C:\Users\jadha\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %% [markdown]
# ## Predicting a new result

# %%
scale_y.inverse_transform([regressor.predict(scale_x.transform([[6.5]]))])
# Out:
# array([[170370.0204065]])

# %% [markdown]
# ## Visualising the SVR results

# %%
plt.scatter(scale_x.inverse_transform(x), scale_y.inverse_transform(y), color = 'red')
plt.plot(scale_x.inverse_transform(x), scale_y.inverse_transform(regressor.predict(x).reshape(len(regressor.predict(x)),1)), 'blue')
plt.title('Support Vector Regreesion Model')
plt.xlabel('Position Level')
plt.ylabel('Salaries')
plt.show()

# %% [markdown]
# ## Visualising the SVR results (for higher resolution and smoother curve)

# %%
x_grid = np.arange(min(scale_x.inverse_transform(x)), max(scale_x.inverse_transform(x)), 0.1)
x_grid = x_grid.reshape(len(x_grid), 1)
plt.scatter(scale_x.inverse_transform(x), scale_y.inverse_transform(y), color = 'red')
plt.plot(x_grid, scale_y.inverse_transform(regressor.predict(scale_x.transform(x_grid)).reshape(len(regressor.predict(scale_x.transform(x_grid))), 1)), color = 'blue')
plt.title('Support Vector Regression Model')
plt.xlabel('Position Level')
plt.ylabel('Salaries')
plt.show()
